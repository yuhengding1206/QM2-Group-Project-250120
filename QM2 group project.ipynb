# %%
# Step 1:

# Aden Gulf Visualisation: (Completed)

import pandas as pd
import requests
from io import StringIO
import matplotlib.pyplot as plt

# GitHub URL (unchanged)
url = 'https://github.com/newzealandpaul/Maritime-Pirate-Attacks/raw/main/data/csv/pirate_attacks.csv'

# Use requests to fetch the CSV file content
response = requests.get(url)
data = StringIO(response.text)

# Read the CSV file into a DataFrame
df = pd.read_csv(data)

# Ensure the 'date' column is in datetime format
df['date'] = pd.to_datetime(df['date'])

# Filter data for the period 1995 Q1 to 2020 Q4
start_date = '1995-01-01'
end_date = '2020-12-31'
filtered_data_Aden = df[df['nearest_country'].isin(['YEM', 'SOM', 'ERI', 'DJI'])]
# Apply the date filter to the filtered_data_Aden DataFrame
filtered_data_Aden2 = filtered_data_Aden[(filtered_data_Aden['date'] >= start_date) & (filtered_data_Aden['date'] <= end_date)]

# Reset the index to a default numerical index
filtered_data_Aden2 = filtered_data_Aden2.reset_index()

# Resample the data quarterly and calculate the number of incidents in each quarter
quarterly_counts = filtered_data_Aden2.resample('Q', on='date').size()
quarterly_counts.index.freq = 'Q'

# Convert the index to a quarterly format
quarterly_counts.index = quarterly_counts.index.to_period('Q').strftime('%Y Q%q')

# Ensure the x-axis starts at 1995 Q1, even if there is no data
# Get all quarters between the start and end dates
all_quarters = pd.period_range(start=start_date, end=end_date, freq='Q').strftime('%Y Q%q').tolist()

# Reindex quarterly_counts to include all quarters, filling missing values with 0
quarterly_counts = quarterly_counts.reindex(all_quarters, fill_value=0)

# Plot the time series of pirate attacks
plt.figure(figsize=(12, 6))
plt.plot(quarterly_counts.index, quarterly_counts.values, marker='o', linestyle='-', color='b')
plt.title('Figure 1: Number of Pirate Attacks in Aden Gulf from 1995 Q1 to 2020 Q4')
plt.xlabel('Time (Quarter)')
plt.ylabel('Number of Pirate Attacks')

# Set x-axis ticks to display only Q1 of each year
xticks = [f"{year} Q1" for year in range(1995, 2021)]
xtick_positions = [quarterly_counts.index.get_loc(xtick) for xtick in xticks if xtick in quarterly_counts.index]

plt.xticks(xtick_positions, xticks, rotation=45)

# Add gridlines and adjust layout to avoid overlapping labels
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-65-4dfd0e75459d>:34: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   quarterly_counts = filtered_data_Aden2.resample('Q', on='date').size()
# <ipython-input-65-4dfd0e75459d>:35: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   quarterly_counts.index.freq = 'Q'

# %%
# Guinea Gulf Visualisation: (Completed)

import pandas as pd
import requests
from io import StringIO
import matplotlib.pyplot as plt

# GitHub URL (unchanged)
url = 'https://github.com/newzealandpaul/Maritime-Pirate-Attacks/raw/main/data/csv/pirate_attacks.csv'

# Use requests to fetch the CSV file content
response = requests.get(url)
data = StringIO(response.text)

# Read the CSV file into a DataFrame
df = pd.read_csv(data)

# Ensure the 'date' column is in datetime format
df['date'] = pd.to_datetime(df['date'])

# Filter data for the period 1995 Q1 to 2020 Q4 for Guinea Gulf countries
start_date = '1995-01-01'
end_date = '2020-12-31'
filtered_data_guinea = df[df['nearest_country'].isin(['NGA', 'LBR', 'GHA', 'BEN', 'STP', 'CIV', 'GIN', 'TGO', 'GNQ', 'GAB', 'CMR'])]
filtered_data_guinea2 = filtered_data_guinea[(filtered_data_guinea['date'] >= start_date) & (filtered_data_guinea['date'] <= end_date)]

# Resampling workaround:
# 1. Reset the index before resampling
# 2. Set the frequency after resampling
quarterly_counts = filtered_data_guinea2.reset_index().resample('Q', on='date').size()
quarterly_counts.index.freq = 'Q'

# Convert the index to quarterly format
quarterly_counts.index = quarterly_counts.index.to_period('Q').strftime('%Y Q%q')

# Ensure the x-axis starts at 1995 Q1, even if there is no data
# Get all quarters between the start and end dates
all_quarters = pd.period_range(start=start_date, end=end_date, freq='Q').strftime('%Y Q%q').tolist()

# Reindex quarterly_counts to include all quarters, filling missing values with 0
quarterly_counts = quarterly_counts.reindex(all_quarters, fill_value=0)

# Plot the time series of pirate attacks
plt.figure(figsize=(12, 6))
plt.plot(quarterly_counts.index, quarterly_counts.values, marker='o', linestyle='-', color='b')
plt.title('Figure 2: Number of Pirate Attacks in Guinea Gulf from 1995 Q1 to 2020 Q4')
plt.xlabel('Time (Quarter)')
plt.ylabel('Number of Pirate Attacks')

# Set x-axis ticks to display only Q1 of each year
xticks = [f"{year} Q1" for year in range(1995, 2021)]
xtick_positions = [quarterly_counts.index.get_loc(xtick) for xtick in xticks if xtick in quarterly_counts.index]

plt.xticks(xtick_positions, xticks, rotation=45)

# Add gridlines and adjust layout to avoid overlapping labels
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-64-3a31d1666c8d>:30: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   quarterly_counts = filtered_data_guinea2.reset_index().resample('Q', on='date').size()
# <ipython-input-64-3a31d1666c8d>:31: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   quarterly_counts.index.freq = 'Q'

# %%
# Southeast Asia Visualisation: (Completed)

import pandas as pd
import requests
from io import StringIO
import matplotlib.pyplot as plt

# GitHub URL (unchanged)
url = 'https://github.com/newzealandpaul/Maritime-Pirate-Attacks/raw/main/data/csv/pirate_attacks.csv'

# Use requests to fetch the CSV file content
response = requests.get(url)
data = StringIO(response.text)

# Read the CSV file into a DataFrame
df = pd.read_csv(data)

# Ensure the 'date' column is in datetime format
df['date'] = pd.to_datetime(df['date'])

# Filter data for the period 1995 Q1 to 2020 Q4
start_date = '1995-01-01'
end_date = '2020-12-31'
filtered_data_asia = df[df['nearest_country'].isin(['PHL', 'VNM', 'KHM', 'THA', 'MYS', 'IDN', 'SGP'])]
filtered_data_asia2 = filtered_data_asia[(filtered_data_asia['date'] >= start_date) & (filtered_data_asia['date'] <= end_date)]

# Resample the data quarterly and count the number of incidents in each quarter
quarterly_counts = filtered_data_asia2.resample('Q', on='date').size()

# Convert the index to a quarterly format
quarterly_counts.index = quarterly_counts.index.to_period('Q').strftime('%Y Q%q')

# Plot the time series of pirate attacks
plt.figure(figsize=(12, 6))
plt.plot(quarterly_counts.index, quarterly_counts.values, marker='o', linestyle='-', color='b')
plt.title('Figure 3: Number of Pirate Attacks in Southeast Asia from 1995 Q1 to 2020 Q4')
plt.xlabel('Time (Quarter)')
plt.ylabel('Number of Pirate Attacks')

# Set the x-axis ticks to display only Q1 of each year
xticks = [f"{year} Q1" for year in range(1995, 2021)]
xtick_positions = [i for i, q in enumerate(quarterly_counts.index) if 'Q1' in q]

# Ensure xticks and xtick_positions have the same length
xticks = xticks[:len(xtick_positions)]  # Adjust xticks to match xtick_positions

plt.xticks(xtick_positions, xticks, rotation=45)

# Add gridlines and adjust layout to prevent label overlap
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-63-fbb60c65b350>:28: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   quarterly_counts = filtered_data_asia2.resample('Q', on='date').size()

# %%
# Comparison of the pirate attacks in Aden Gulf & Guinea Gulf & Southeast Asia from 1993 to 2020
import pandas as pd
import requests
from io import StringIO
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline

# GitHub URL (do not modify)
url = 'https://github.com/newzealandpaul/Maritime-Pirate-Attacks/raw/main/data/csv/pirate_attacks.csv'

# Use requests to fetch the CSV file content
response = requests.get(url)
data = StringIO(response.text)

# Read the CSV file
df = pd.read_csv(data)

# Ensure the 'date' column is in datetime format
df['date'] = pd.to_datetime(df['date'])

# Define the date range
start_date = '1995-01-01'
end_date = '2020-12-31'

# Filter data for Aden Gulf
filtered_data_Aden = df[df['nearest_country'].isin(['YEM', 'SOM', 'ERI', 'DJI'])]
filtered_data_Aden = filtered_data_Aden[(filtered_data_Aden['date'] >= start_date) & (filtered_data_Aden['date'] <= end_date)]
quarterly_counts_Aden = filtered_data_Aden.resample('Q', on='date').size()

# Filter data for Gulf of Guinea
filtered_data_Guinea = df[df['nearest_country'].isin(['NGA', 'LBR', 'GHA', 'BEN', 'STP', 'CIV', 'GIN', 'TGO', 'GNQ', 'GAB', 'CMR'])]
filtered_data_Guinea = filtered_data_Guinea[(filtered_data_Guinea['date'] >= start_date) & (filtered_data_Guinea['date'] <= end_date)]
quarterly_counts_Guinea = filtered_data_Guinea.resample('Q', on='date').size()

# Filter data for Asia
filtered_data_Asia = df[df['nearest_country'].isin(['PHL', 'VNM', 'KHM', 'THA', 'MYS', 'IDN', 'SGP'])]
filtered_data_Asia = filtered_data_Asia[(filtered_data_Asia['date'] >= start_date) & (filtered_data_Asia['date'] <= end_date)]
quarterly_counts_Asia = filtered_data_Asia.resample('Q', on='date').size()

# Convert indices to quarterly format
quarterly_counts_Aden.index = quarterly_counts_Aden.index.to_period('Q').strftime('%Y Q%q')
quarterly_counts_Guinea.index = quarterly_counts_Guinea.index.to_period('Q').strftime('%Y Q%q')
quarterly_counts_Asia.index = quarterly_counts_Asia.index.to_period('Q').strftime('%Y Q%q')

# Ensure quarterly_counts_Aden has all quarters from 1995 Q1 to 2020 Q4
all_quarters = pd.period_range(start=start_date, end=end_date, freq='Q').strftime('%Y Q%q').tolist()
quarterly_counts_Aden = quarterly_counts_Aden.reindex(all_quarters, fill_value=0)
quarterly_counts_Guinea = quarterly_counts_Guinea.reindex(all_quarters, fill_value=0)
quarterly_counts_Asia = quarterly_counts_Asia.reindex(all_quarters, fill_value=0)


# Function to create smooth curves
def smooth_curve(x, y):
    x_new = np.linspace(0, len(x) - 1, 300)  # 300 points for smoothness
    spline = make_interp_spline(np.arange(len(x)), y, k=3)  # Cubic spline
    y_new = spline(x_new)
    return x_new, y_new

# Smooth the data
x_Aden, y_Aden = smooth_curve(quarterly_counts_Aden.index, quarterly_counts_Aden.values)
x_Guinea, y_Guinea = smooth_curve(quarterly_counts_Guinea.index, quarterly_counts_Guinea.values)
x_Asia, y_Asia = smooth_curve(quarterly_counts_Asia.index, quarterly_counts_Asia.values)

plt.figure(figsize=(12, 6))
plt.plot(x_Aden, y_Aden, color='b', label='Aden Gulf')
plt.plot(x_Guinea, y_Guinea, color='g', label='Guinea Gulf')
plt.plot(x_Asia, y_Asia, color='r', label='Southeast Asia')

plt.title('Figure 4:Number of Pirate Attacks in Aden Gulf & Guinea Gulf & Southeast Asia from 1995 Q1 to 2020 Q4')
plt.xlabel('Time (Quarter)')
plt.ylabel('Number of Pirate Attacks')

# Set x-axis ticks to display only Q1 of each year
xticks = [f"{year} Q1" for year in range(1995, 2021)]
xtick_positions = [quarterly_counts_Aden.index.get_loc(xtick) for xtick in xticks if xtick in quarterly_counts_Aden.index]

plt.xticks(xtick_positions, xticks, rotation=45)  # Rotate x-axis labels for better readability

# Add a label for the vertical line
plt.axvline(x=quarterly_counts_Aden.index.get_loc('2008 Q4'), color='Purple', linestyle='--',label='Intervention Starts')

# Adjust legend position to ensure the label is included
plt.legend(loc='upper right')

plt.grid()
plt.tight_layout()  # Adjust layout to avoid label overlap
plt.show()
# Out:
# <ipython-input-24-3924d4578317>:29: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   quarterly_counts_Aden = filtered_data_Aden.resample('Q', on='date').size()
# <ipython-input-24-3924d4578317>:34: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   quarterly_counts_Guinea = filtered_data_Guinea.resample('Q', on='date').size()
# <ipython-input-24-3924d4578317>:39: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   quarterly_counts_Asia = filtered_data_Asia.resample('Q', on='date').size()

# %%
# Parallel Analysis for Aden Gulf and Guinea Gulf: (Completed)

import pandas as pd
import requests
from io import StringIO
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.formula.api import ols

# Load data
url = 'https://github.com/newzealandpaul/Maritime-Pirate-Attacks/raw/main/data/csv/pirate_attacks.csv'
response = requests.get(url)
data = StringIO(response.text)
df = pd.read_csv(data)

# Ensure 'date' column is datetime
df['date'] = pd.to_datetime(df['date'])

# Filter data for the relevant time period
start_date = '1995-01-01'
end_date = '2008-12-31'  # Change to before the policy implementation
df = df[(df['date'] >= start_date) & (df['date'] <= end_date)]

# Define treatment and control groups
# Treatment group: Aden Gulf (Yemen and Somalia)
# Control group: Southeast Asia (specific countries)
df['treatment'] = np.where(df['nearest_country'].isin(['YEM', 'SOM', 'ERI', 'DJI']), 1,
                            np.where(df['nearest_country'].isin(['NGA', 'LBR', 'GHA', 'BEN', 'STP', 'CIV', 'GIN', 'TGO', 'GNQ', 'GAB', 'CMR']), 0, np.nan))

# Remove rows where treatment is NaN (not in either group)
df = df.dropna(subset=['treatment'])

# Create quarter variable
df['quarter'] = df['date'].dt.to_period('Q')  # Create period-based quarter
agg_df = df.groupby(['quarter', 'treatment']).size().reset_index(name='num_attacks')

# Convert 'quarter' to string for plotting
agg_df['quarter'] = agg_df['quarter'].astype(str)

# Ensure all quarters from 1995 Q1 to 2008 Q4 are present
all_quarters = pd.period_range(start='1995Q1', end='2008Q4', freq='Q').astype(str).tolist()
idx = pd.MultiIndex.from_product([all_quarters, [0, 1]], names=['quarter', 'treatment'])
agg_df = agg_df.set_index(['quarter', 'treatment']).reindex(idx, fill_value=0).reset_index()

# Visualize the trends for treatment and control groups
plt.figure(figsize=(12, 6))
sns.lineplot(data=agg_df[agg_df['treatment'] == 0], x='quarter', y='num_attacks', marker='o', label='Guinea Gulf', color='green')
sns.lineplot(data=agg_df[agg_df['treatment'] == 1], x='quarter', y='num_attacks', marker='o', label='Aden Gulf', color='blue')

# Add vertical dashed line for intervention start at 2008 Q4
plt.axvline(x='2008Q4', color='purple', linestyle='--', linewidth=2, label='Intervention Starts')

plt.title('Figure 5: Trends in Pirate Attacks in Aden Gulf & Guinea Gulf Before Operation Atalanta (1995 Q1 - 2008 Q4)')
plt.ylabel('Number of Pirate Attacks')
plt.xlabel('Time (Quarter)')

# Change x-tick labels to show corresponding year and "Q1" for all Q1s
unique_quarters = agg_df['quarter'].unique()
plt.xticks(
    ticks=np.arange(len(unique_quarters)),
    labels=[f"{quarter.split('Q')[0]} Q1" if 'Q1' in quarter else '' for quarter in unique_quarters],
    rotation=45
)

# Add grid
plt.grid(True)  # Ensure grid is enabled

# Move legend to upper left
plt.grid(True)  # Ensure grid is enabled
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()

# Run regression to test for parallel trends
agg_df['time'] = np.arange(len(agg_df))  # Create a time variable for the regression and name it 'time'

# Run the regression for the pre-policy period
pre_did_model = ols('num_attacks ~ treatment + time + treatment*time', data=agg_df).fit()
print(pre_did_model.summary())  # Added parenthesis here

# Conclusion based on the regression results
if pre_did_model.pvalues['treatment:time'] < 0.05:
    print("Therefore: The assumptions for a parallel analysis are not met.")
else:
    print("Therefore: The assumptions for a parallel analysis are met.")
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            num_attacks   R-squared:                       0.314
# Model:                            OLS   Adj. R-squared:                  0.295
# Method:                 Least Squares   F-statistic:                     16.49
# Date:                Thu, 16 Jan 2025   Prob (F-statistic):           6.83e-09
# Time:                        09:37:39   Log-Likelihood:                -351.42
# No. Observations:                 112   AIC:                             710.8
# Df Residuals:                     108   BIC:                             721.7
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          3.0000      1.498      2.003      0.048       0.031       5.969
# ...

# %%
# Parallel Analysis for Aden Gulf and Southeast Asia: (Completed)

import pandas as pd
import requests
from io import StringIO
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.formula.api import ols

# Load data
url = 'https://github.com/newzealandpaul/Maritime-Pirate-Attacks/raw/main/data/csv/pirate_attacks.csv'
response = requests.get(url)
data = StringIO(response.text)
df = pd.read_csv(data)

# Ensure 'date' column is datetime
df['date'] = pd.to_datetime(df['date'])

# Filter data for the relevant time period
start_date = '1995-01-01'
end_date = '2008-12-31'  # Change to before the policy implementation
df = df[(df['date'] >= start_date) & (df['date'] <= end_date)]

# Define treatment and control groups
# Treatment group: Aden Gulf (Yemen and Somalia)
# Control group: Southeast Asia (specific countries)
df['treatment'] = np.where(df['nearest_country'].isin(['YEM', 'SOM', 'ERI', 'DJI']), 1,
                            np.where(df['nearest_country'].isin(['PHL', 'VNM', 'KHM', 'THA', 'MYS', 'IDN', 'SGP']), 0, np.nan))

# Remove rows where treatment is NaN (not in either group)
df = df.dropna(subset=['treatment'])

# Create quarter variable
df['quarter'] = df['date'].dt.to_period('Q')  # Create period-based quarter
agg_df = df.groupby(['quarter', 'treatment']).size().reset_index(name='num_attacks')

# Convert 'quarter' to string for plotting
agg_df['quarter'] = agg_df['quarter'].astype(str)

# **Fix for incomplete data: Ensure all quarters from 1995 Q1 to 2008 Q4 are present**
all_quarters = pd.period_range(start='1995Q1', end='2008Q4', freq='Q').astype(str).tolist()
idx = pd.MultiIndex.from_product([all_quarters, [0, 1]], names=['quarter', 'treatment'])
agg_df = agg_df.set_index(['quarter', 'treatment']).reindex(idx, fill_value=0).reset_index()

# Visualize the trends for treatment and control groups
plt.figure(figsize=(12, 6))
sns.lineplot(data=agg_df[agg_df['treatment'] == 0], x='quarter', y='num_attacks', marker='o', label='Southeast Asia', color='red')
sns.lineplot(data=agg_df[agg_df['treatment'] == 1], x='quarter', y='num_attacks', marker='o', label='Aden Gulf', color='blue')

# Add vertical dashed line for intervention start at 2008 Q4
plt.axvline(x='2008Q4', color='purple', linestyle='--', linewidth=2, label='Intervention Starts')

plt.title('Figure 6: Trends in Pirate Attacks in Aden Gulf & Southeast Asia Before Operation Atalanta (1995 Q1 - 2008 Q4)')
plt.ylabel('Number of Pirate Attacks')
plt.xlabel('Time (Quarter)')

# Change x-tick labels to show corresponding year and "Q1" for all Q1s
unique_quarters = agg_df['quarter'].unique()
plt.xticks(ticks=np.arange(len(unique_quarters)),
           labels=[f"{quarter.split('Q')[0]} Q1" if 'Q1' in quarter else '' for quarter in unique_quarters], rotation=45)

# Add grid
plt.grid(True)  # Ensure grid is enabled
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()

# Run regression to test for parallel trends
agg_df['time'] = np.arange(len(agg_df))  # Create a time variable for the regression and name it 'time'

# Run the regression for the pre-policy period
pre_did_model = ols('num_attacks ~ treatment + time + treatment*time', data=agg_df).fit()
print(pre_did_model.summary())  # Added parenthesis here

# Conclusion based on the regression results
if pre_did_model.pvalues['treatment:time'] < 0.05:
    print("Therefore: The assumptions for a parallel analysis are not met.")
else:
    print("Therefore: The assumptions for a parallel analysis are met.")
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            num_attacks   R-squared:                       0.555
# Model:                            OLS   Adj. R-squared:                  0.543
# Method:                 Least Squares   F-statistic:                     44.98
# Date:                Thu, 16 Jan 2025   Prob (F-statistic):           6.10e-19
# Time:                        09:38:08   Log-Likelihood:                -432.42
# No. Observations:                 112   AIC:                             872.8
# Df Residuals:                     108   BIC:                             883.7
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept         31.9023      3.087     10.334      0.000      25.783      38.021
# ...

# %%
# Differences in differences analysis for Aden Gulf and Guinea Gulf: (Completed)
import pandas as pd
import requests
from io import StringIO
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.formula.api import ols

# Load data
url = 'https://github.com/newzealandpaul/Maritime-Pirate-Attacks/raw/main/data/csv/pirate_attacks.csv'
response = requests.get(url)
data = StringIO(response.text)
df = pd.read_csv(data)

# Ensure 'date' column is datetime
df['date'] = pd.to_datetime(df['date'])

# Filter data for the relevant time period
start_date = '1993-01-01'
end_date = '2020-12-31'  # Updated to include data until the end of 2020
df = df[(df['date'] >= start_date) & (df['date'] <= end_date)]

# Define treatment and control groups
df['treatment'] = np.where(df['nearest_country'].isin(['YEM', 'SOM', 'ERI', 'DJI']), 1,
                            np.where(df['nearest_country'].isin(['NGA', 'LBR', 'GHA', 'BEN', 'STP', 'CIV', 'GIN', 'TGO', 'GNQ', 'GAB', 'CMR']), 0, np.nan))

# Remove rows where treatment is NaN (not in either group)
df = df.dropna(subset=['treatment'])

# Create quarter variable
df['quarter'] = df['date'].dt.to_period('Q')  # Create period-based quarter
agg_df = df.groupby(['quarter', 'treatment']).size().reset_index(name='num_attacks')

# Convert 'quarter' to string for plotting
agg_df['quarter'] = agg_df['quarter'].astype(str)

# Create 'post' variable:
agg_df['post'] = np.where((agg_df['quarter'] >= '2010Q1') & (agg_df['quarter'] <= '2020Q4'), 1, 0)
agg_df['post_treatment'] = agg_df['post'] * agg_df['treatment']

# Run DID regression
did_model = ols('num_attacks ~ post + treatment + post_treatment', data=agg_df).fit()
print(did_model.summary())

# Visualize boxplot for pre and post periods by treatment group
agg_df['category'] = agg_df['treatment'].astype(str) + agg_df['post'].astype(str)

# Define colors for each group
palette = {0: 'green', 1: 'blue'}  # Control group in green, Treatment group in blue

# Use agg_df for the boxplot data
sns.boxplot(x='category', y='num_attacks', hue='treatment', data=agg_df, palette=palette).set_xticklabels(
    ['Pre Control', 'Pre Treatment', 'Post Control', 'Post Treatment']  # Updated labels
)

plt.title('Figure 7: Number of Pirate Attacks by Treatment and Post Periods')
plt.xlabel('')
plt.ylabel('Number of Pirate Attacks')

# Custom legend to match colors
handles = [plt.Line2D([0], [0], marker='o', color='w', label='Guinea Gulf (Control)',
                       markerfacecolor='green', markersize=10),
           plt.Line2D([0], [0], marker='o', color='w', label='Aden Gulf (Treatment)',
                       markerfacecolor='blue', markersize=10)]
plt.legend(handles=handles, title='Region')  # Use custom handles for the legend

plt.tight_layout()
plt.show()

# The regression was using df instead of agg_df, which has 'post', 'treatment', 'post_treatment', and 'num_attacks'
df_model = ols('num_attacks ~ post + treatment + post_treatment', data=agg_df).fit()
print(df_model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            num_attacks   R-squared:                       0.026
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     1.639
# Date:                Thu, 16 Jan 2025   Prob (F-statistic):              0.182
# Time:                        11:04:40   Log-Likelihood:                -688.02
# No. Observations:                 189   AIC:                             1384.
# Df Residuals:                     185   BIC:                             1397.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          7.9672      1.193      6.677      0.000       5.613      10.321
# ...

# %%
# Differences in differences analysis for Aden Gulf and Southeast Asia: (Completed)

import pandas as pd
import requests
from io import StringIO
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.formula.api import ols

# Load data
url = 'https://github.com/newzealandpaul/Maritime-Pirate-Attacks/raw/main/data/csv/pirate_attacks.csv'
response = requests.get(url)
data = StringIO(response.text)
df = pd.read_csv(data)

# Ensure 'date' column is datetime
df['date'] = pd.to_datetime(df['date'])

# Filter data for the relevant time period
start_date = '1993-01-01'
end_date = '2020-12-31'  # Updated to include data until the end of 2020
df = df[(df['date'] >= start_date) & (df['date'] <= end_date)]

# Define treatment and control groups
# Treatment group: Aden Gulf (Yemen and Somalia)
# Control group: Southeast Asia (specific countries)
df['treatment'] = np.where(df['nearest_country'].isin(['YEM', 'SOM', 'ERI', 'DJI']), 1,
                            np.where(df['nearest_country'].isin(['PHL', 'VNM', 'KHM', 'THA', 'MYS', 'IDN', 'SGP']), 0, np.nan))

# Remove rows where treatment is NaN (not in either group)
df = df.dropna(subset=['treatment'])

# Create quarter variable
df['quarter'] = df['date'].dt.to_period('Q')  # Create period-based quarter
agg_df = df.groupby(['quarter', 'treatment']).size().reset_index(name='num_attacks')

# Convert 'quarter' to string for plotting
agg_df['quarter'] = agg_df['quarter'].astype(str)

# Create 'post' variable:
agg_df['post'] = np.where((agg_df['quarter'] >= '2010Q1') & (agg_df['quarter'] <= '2020Q4'), 1, 0)
agg_df['post_treatment'] = agg_df['post'] * agg_df['treatment']

# Run DID regression
did_model = ols('num_attacks ~ post + treatment + post_treatment', data=agg_df).fit()
print(did_model.summary())

# Visualize boxplot for pre and post periods by treatment group
agg_df['category'] = agg_df['treatment'].astype(str) + agg_df['post'].astype(str)

# Define colors for each group
palette = {0: 'red', 1: 'blue'}  # Control group in red, Treatment group in blue

# Use agg_df for the boxplot data
sns.boxplot(x='category', y='num_attacks', hue='treatment', data=agg_df, palette=palette).set_xticklabels(
    ['Pre x Control', 'Pre x Treatment', 'Post x Control', 'Post x Treatment']
)

plt.title('Figure 8: Number of Pirate Attacks by Treatment and Post Periods')
plt.xlabel('')
plt.ylabel('Number of Pirate Attacks')

# Custom legend to match colors
handles = [plt.Line2D([0], [0], marker='o', color='w', label='Southeast Asia (Control)',
                       markerfacecolor='red', markersize=10),
           plt.Line2D([0], [0], marker='o', color='w', label='Aden Gulf (Treatment)',
                       markerfacecolor='blue', markersize=10)]
plt.legend(handles=handles, title='Region')  # Use custom handles for the legend

plt.tight_layout()
plt.show()

# The regression was using df instead of agg_df, which has 'post', 'treatment', 'post_treatment', and 'num_attacks'
df_model = ols('num_attacks ~ post + treatment + post_treatment', data=agg_df).fit()
print(df_model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            num_attacks   R-squared:                       0.301
# Model:                            OLS   Adj. R-squared:                  0.290
# Method:                 Least Squares   F-statistic:                     27.54
# Date:                Thu, 16 Jan 2025   Prob (F-statistic):           7.40e-15
# Time:                        11:06:39   Log-Likelihood:                -784.55
# No. Observations:                 196   AIC:                             1577.
# Df Residuals:                     192   BIC:                             1590.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept         27.9853      1.623     17.240      0.000      24.784      31.187
# ...

# %%
# Second Part:

import pandas as pd
import requests
from io import StringIO

# GitHub URL (unchanged)
url = 'https://github.com/newzealandpaul/Maritime-Pirate-Attacks/raw/main/data/csv/pirate_attacks.csv'

# Use requests to fetch the CSV file content
response = requests.get(url)
data = StringIO(response.text)

# Load the CSV file into a DataFrame
df = pd.read_csv(data)

# Ensure the 'date' column is in datetime format
df['date'] = pd.to_datetime(df['date'])

# Define the list of countries in the Gulf of Guinea region (with corresponding ISO codes)
guinea_gulf_countries = ['NGA', 'BEN', 'TGO', 'GHA', 'CIV', 'CMR']

# Filter the data for the Gulf of Guinea region
filtered_data_Guinea_Gulf = df[df['nearest_country'].isin(guinea_gulf_countries)]

# Ensure the data is within the range of 2000 to 2020
start_date = '2000-01-01'
end_date = '2020-12-31'
filtered_data_Guinea_Gulf = filtered_data_Guinea_Gulf[(filtered_data_Guinea_Gulf['date'] >= start_date) & (filtered_data_Guinea_Gulf['date'] <= end_date)]

# Calculate the number of pirate attacks per year
annual_counts = filtered_data_Guinea_Gulf.set_index('date').resample('Y').size()

# Filter the data for years 2000 to 2020
annual_counts_filtered = annual_counts[(annual_counts.index.year >= 2000) & (annual_counts.index.year <= 2020)]

# Output the number of pirate attacks in the Gulf of Guinea from 2000 to 2020
print("Pirate Attacks in Gulf of Guinea from 2000 to 2020:")
total_attacks = 0
for year in range(2000, 2021):
    count = annual_counts_filtered.get(pd.Timestamp(f"{year}-12-31"), 0)  # Get the data for each year
    total_attacks += count
    print(f"{year}: {count} attacks")

print(f"\nTotal attacks from 2000 to 2020: {total_attacks} attacks")
# Out:
# Pirate Attacks in Gulf of Guinea from 2000 to 2020:
# 2000: 19 attacks
# 2001: 40 attacks
# 2002: 30 attacks
# 2003: 48 attacks
# 2004: 39 attacks
# 2005: 25 attacks
# 2006: 16 attacks
# 2007: 41 attacks
# 2008: 53 attacks
# 2009: 39 attacks
# 2010: 28 attacks
# 2011: 39 attacks
# 2012: 48 attacks
# 2013: 41 attacks
# 2014: 28 attacks
# 2015: 20 attacks
# 2016: 41 attacks
# 2017: 39 attacks
# 2018: 71 attacks
# 2019: 49 attacks
# 2020: 55 attacks
#
# Total attacks from 2000 to 2020: 809 attacks
# <ipython-input-48-e79e97583b35>:34: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   annual_counts = filtered_data_Guinea_Gulf.set_index('date').resample('Y').size()

# %%
# Second Part: The average number of ships that experienced one pirate attack (variable: Per_Attack)
# Data Set: (Completed)

import pandas as pd
import requests
from io import StringIO

# GitHub URL (updated to raw content URL)
url = 'https://raw.githubusercontent.com/yuhengding1206/QM2-2024/main/Per%20Attack%20Statistics.csv' # Changed to raw content URL

# Use requests to fetch the CSV file content
response = requests.get(url)

# Read the CSV file using read_csv (since it's a CSV)
# Decode the bytes content to a string using 'utf-8'
df = pd.read_csv(StringIO(response.content.decode('utf-8')))
print(df)
# Out:
#     Year          Region  Per_Attack
# 0   2000       Aden_Gulf         615
# 1   2000     Guinea_Gulf         215
# 2   2000  Southeast_Asia         219
# 3   2001       Aden_Gulf         699
# 4   2001     Guinea_Gulf         112
# ..   ...             ...         ...
# 58  2019     Guinea_Gulf          67
# 59  2019  Southeast_Asia        1550
# 60  2020       Aden_Gulf        6277
# 61  2020     Guinea_Gulf          74
# 62  2020  Southeast_Asia        1272
#
# [63 rows x 3 columns]

# %%
# Visualisation for per_attack: (Completed)

import pandas as pd
import requests
from io import StringIO
import matplotlib.pyplot as plt

# GitHub URL (updated to raw content URL)
url = 'https://raw.githubusercontent.com/yuhengding1206/QM2-Project/main/cleaned_piracy_data_with_calculations.csv'

# Use requests to fetch the CSV file content
response = requests.get(url)

# Read the CSV file using read_csv
df = pd.read_csv(StringIO(response.content.decode('utf-8')))

# Select the desired columns
selected_data = df[['Year', 'Aden_per_attack', 'Southeast_asia_per_attack', 'Guinea_per_attack']]

# Filter for the specific years
filtered_data = selected_data[(selected_data['Year'] >= 1993) & (selected_data['Year'] <= 2020)]

# Plotting
plt.figure(figsize=(12, 6))

# Plotting the data for each region with specified colors
plt.plot(filtered_data['Year'], filtered_data['Aden_per_attack'], label='Aden per Attack', marker='o', color='blue')
plt.plot(filtered_data['Year'], filtered_data['Southeast_asia_per_attack'], label='Southeast Asia per Attack', marker='o', color='red')
plt.plot(filtered_data['Year'], filtered_data['Guinea_per_attack'], label='Guinea per Attack', marker='o', color='green')

# Draw a vertical dashed line at the year 2009
plt.axvline(x=2009, color='purple', linestyle='--', label='Intervention Starts')

# Adding labels and title
plt.title('Figure 9: Pirate per Attacks in Aden Gulf, Guinea Gulf & Southeast Asia from 1993 to 2020')
plt.xlabel('Year')
plt.ylabel('Number of Attacks per Region')
plt.xticks(filtered_data['Year'])  # Set x-ticks to show each year
plt.legend()
plt.grid()

# Show the plot
plt.show()

# %%
# Parallel Analysis for Aden Gulf and Guinea Gulf:

import pandas as pd
import requests
from io import StringIO
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import statsmodels.formula.api as smf

# GitHub CSV data URL
url = 'https://raw.githubusercontent.com/yuhengding1206/QM2-2024/main/Per%20Attack%20Statistics.csv'

# Load the CSV data from GitHub
response = requests.get(url)
df = pd.read_csv(StringIO(response.content.decode('utf-8')))

# Filter for Aden Gulf and Guinea Gulf regions
df = df[df['Region'].isin(['Aden_Gulf', 'Guinea_Gulf'])]

# Convert the Year column to numeric
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')

# Create a variable indicating whether the year is post-2009
df['post'] = np.where(df['Year'] >= 2010, 1, 0)

# Create treatment and control group variables
df['treatment'] = np.where(df['Region'] == 'Aden_Gulf', 1,
                           np.where(df['Region'] == 'Guinea_Gulf', 0, np.nan))

# Create an interaction term for post-treatment
df['post_treatment'] = df['post'] * df['treatment']

# Create a time variable
df['time'] = df['Year']

# Filter data for 2000-2009
df_pre_2009 = df[(df['Year'] >= 2000) & (df['Year'] < 2010)]

# Plot trends for each region
plt.figure(figsize=(12, 6))
# Set the color for Guinea Gulf to green
sns.lineplot(data=df_pre_2009, x='Year', y='Per_Attack', hue='Region', marker='o', palette={'Aden_Gulf': 'blue', 'Guinea_Gulf': 'green'})
plt.title('Figure 10:Attack Count Trend (2000-2009) for Aden Gulf and Guinea Gulf')
plt.xlabel('Year')
plt.ylabel('Number of Attacks (Per Attack)')
plt.axvline(x=2009, color='purple', linestyle='--', label='Intervention Starts')
plt.legend()
plt.grid(True, linestyle='--', linewidth=0.7)
plt.show()

# Fit the regression model for pre-2010 data
pre_df_model = smf.ols('Per_Attack ~ treatment + time + treatment*time', data=df[df['Year'] < 2010]).fit()
print(pre_df_model.summary())

# Conclusion based on the regression results
if pre_df_model.pvalues['treatment:time'] < 0.05:
    print("Therefore: The assumptions for a parallel analysis are not met.")
else:
    print("Therefore: The assumptions for a parallel analysis are met.")
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             Per_Attack   R-squared:                       0.539
# Model:                            OLS   Adj. R-squared:                  0.452
# Method:                 Least Squares   F-statistic:                     6.231
# Date:                Thu, 16 Jan 2025   Prob (F-statistic):            0.00525
# Time:                        11:11:39   Log-Likelihood:                -138.98
# No. Observations:                  20   AIC:                             286.0
# Df Residuals:                      16   BIC:                             289.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept       6196.9455   6.22e+04      0.100      0.922   -1.26e+05    1.38e+05
# ...

# %%
# Parallel Analysis for Aden Gulf and Southeast Asia:

import pandas as pd
import requests
from io import StringIO
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import statsmodels.formula.api as smf

# GitHub CSV Data URL
url = 'https://raw.githubusercontent.com/yuhengding1206/QM2-2024/main/Per%20Attack%20Statistics.csv'

# Load the data from GitHub
response = requests.get(url)
df = pd.read_csv(StringIO(response.content.decode('utf-8')))

# Filter the data to only include Aden Gulf and Southeast Asia
df = df[df['Region'].isin(['Aden_Gulf', 'Southeast_Asia'])]

# Convert the Year column to a numeric type
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')

# Create a variable to indicate whether the year is after 2009
df['post'] = np.where(df['Year'] >= 2010, 1, 0)

# Create variables for treatment and control groups
df['treatment'] = np.where(df['Region'] == 'Aden_Gulf', 1,
                           np.where(df['Region'] == 'Southeast_Asia', 0, np.nan))

# Create an interaction term to indicate post-intervention status
df['post_treatment'] = df['post'] * df['treatment']

# Filter data for the years 2000-2009
df_pre_2009 = df[(df['Year'] >= 2000) & (df['Year'] < 2010)]

# Plot the trend graph, showing attack counts per year
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_pre_2009, x='Year', y='Per_Attack', hue='Region', marker='o',
             palette={'Aden_Gulf': 'blue', 'Southeast_Asia': 'red'})  # Set colors for regions
plt.title('Attack Count Trend (2000-2009) for Aden Gulf and Southeast Asia')
plt.xlabel('Year')
plt.ylabel('Number of Attacks (Per Attack)')
plt.axvline(x=2009, color='purple', linestyle='--', label='Intervention Starts')
plt.legend(title='Region')

# Add a grid
plt.grid(True, linestyle='--', linewidth=0.7)

plt.show()

# Create a 'time' variable within the DataFrame before using it in the OLS formula
# Assume 'Year' represents the time variable, so assign it to 'time'
df['time'] = df['Year']

# Fit the regression model for pre-2010 data
pre_df_model = smf.ols('Per_Attack ~ treatment + time + treatment*time', data=df[df['Year'] < 2010]).fit()
print(pre_df_model.summary())

# Conclusion based on the regression results
if pre_df_model.pvalues['treatment:time'] < 0.05:
    print("Therefore: The assumptions for a parallel analysis are not met.")
else:
    print("Therefore: The assumptions for a parallel analysis are met.")
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             Per_Attack   R-squared:                       0.468
# Model:                            OLS   Adj. R-squared:                  0.368
# Method:                 Least Squares   F-statistic:                     4.692
# Date:                Thu, 16 Jan 2025   Prob (F-statistic):             0.0155
# Time:                        11:13:50   Log-Likelihood:                -139.52
# No. Observations:                  20   AIC:                             287.0
# Df Residuals:                      16   BIC:                             291.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept      -2.109e+05   6.39e+04     -3.300      0.005   -3.46e+05   -7.54e+04
# ...

# %%
# Did Analysis for Aden Gulf and Guinea Gulf: (Completed)
import pandas as pd
import requests
from io import StringIO
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from statsmodels.formula.api import ols

# GitHub CSV Data URL
url = 'https://raw.githubusercontent.com/yuhengding1206/QM2-2024/main/Per%20Attack%20Statistics.csv'

# Load data from GitHub
response = requests.get(url)
df = pd.read_csv(StringIO(response.content.decode('utf-8')))

# Filter the dataset to include only Aden Gulf and Guinea Gulf
df = df[df['Region'].isin(['Aden_Gulf', 'Guinea_Gulf'])]

# Convert the 'Year' column to numeric type
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')

# Create a variable indicating whether the year is post-2009
df['post'] = np.where(df['Year'] >= 2010, 1, 0)

# Create treatment and control group variables
df['treatment'] = np.where(df['Region'] == 'Aden_Gulf', 1,
                           np.where(df['Region'] == 'Guinea_Gulf', 0, np.nan))

# Create an interaction variable to represent the post-intervention state
df['post_treatment'] = df['post'] * df['treatment']

# Create a categorical variable combining treatment and post-period indicators
df['category'] = df['treatment'].astype(str) + df['post'].astype(str)

# Plot a boxplot showing the number of pirate attacks across the categories
sns.boxplot(x='category', y='Per_Attack', hue='treatment', data=df).set_xticklabels(
    ['Pre x Control', 'Pre x Treatment', 'Post x Control', 'Post x Treatment']
)
plt.title('Number of Pirate Attacks by Treatment and Post Periods')
plt.xlabel('')
plt.ylabel('Number of Pirate Attacks')
plt.legend(title='Region')
plt.tight_layout()
plt.show()

# Perform a Differences-in-Differences (DiD) regression
df_model = ols('Per_Attack ~  post + treatment + post_treatment', df).fit()
print(df_model.summary())
# Out:
# <ipython-input-12-9f48fed55f19>:37: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   sns.boxplot(x='category', y='Per_Attack', hue='treatment', data=df).set_xticklabels(
#                             OLS Regression Results
# ...
# Dep. Variable:             Per_Attack   R-squared:                       0.475
# Model:                            OLS   Adj. R-squared:                  0.434
# Method:                 Least Squares   F-statistic:                     11.46
# Date:                Thu, 16 Jan 2025   Prob (F-statistic):           1.71e-05
# Time:                        09:43:32   Log-Likelihood:                -362.47
# No. Observations:                  42   AIC:                             732.9
# Df Residuals:                      38   BIC:                             739.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ...

# %%
# Did Analysis for Aden Gulf and Guinea Gulf: (Completed)
import pandas as pd
import requests
from io import StringIO
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from statsmodels.formula.api import ols

# GitHub CSV Data URL
url = 'https://raw.githubusercontent.com/yuhengding1206/QM2-2024/main/Per%20Attack%20Statistics.csv'

# Load data from GitHub
response = requests.get(url)
df = pd.read_csv(StringIO(response.content.decode('utf-8')))

# Filter the dataset to include only Aden Gulf and Guinea Gulf
df = df[df['Region'].isin(['Aden_Gulf', 'Guinea_Gulf'])]

# Convert the 'Year' column to numeric type
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')

# Create a variable indicating whether the year is post-2009
df['post'] = np.where(df['Year'] >= 2010, 1, 0)

# Create treatment and control group variables
df['treatment'] = np.where(df['Region'] == 'Aden_Gulf', 1,  # Treatment group for Aden Gulf
                           np.where(df['Region'] == 'Guinea_Gulf', 0, np.nan))  # Control group for Guinea Gulf

# Create an interaction variable to represent the post-intervention state
df['post_treatment'] = df['post'] * df['treatment']

# Create a categorical variable combining treatment and post-period indicators
df['category'] = df['treatment'].astype(str) + df['post'].astype(str)  # Adjust category based on correct groups

# Define color palette to swap colors for the boxplot
palette = {'Aden_Gulf': 'red', 'Guinea_Gulf': 'blue'}  # Swap the colors

# Plot a boxplot showing the number of pirate attacks across the categories
sns.boxplot(x='category', y='Per_Attack', hue='Region', data=df, palette=palette).set_xticklabels(
    ['Control (Guinea, Pre)', 'Treatment (Aden, Pre)', 'Control (Guinea, Post)', 'Treatment (Aden, Post)']
)
plt.title('Number of Pirate Attacks by Treatment and Post Periods')
plt.xlabel('')
plt.ylabel('Number of Pirate Attacks')
plt.legend(title='Region')
plt.tight_layout()
plt.show()

# Perform a Differences-in-Differences (DiD) regression
df_model = ols('Per_Attack ~ post + treatment + post_treatment', df).fit()
print(df_model.summary())
# Out:
# <ipython-input-41-d75fb564d87c>:40: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   sns.boxplot(x='category', y='Per_Attack', hue='Region', data=df, palette=palette).set_xticklabels(
#                             OLS Regression Results
# ...
# Dep. Variable:             Per_Attack   R-squared:                       0.475
# Model:                            OLS   Adj. R-squared:                  0.434
# Method:                 Least Squares   F-statistic:                     11.46
# Date:                Thu, 16 Jan 2025   Prob (F-statistic):           1.71e-05
# Time:                        11:18:17   Log-Likelihood:                -362.47
# No. Observations:                  42   AIC:                             732.9
# Df Residuals:                      38   BIC:                             739.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ...

# %%
# Did Analysis for Aden Gulf and Southeast Asia: (Completed) (The parallel analysis did not stand, but I still kept the graphs for Differences in differences)
import pandas as pd
import requests
from io import StringIO
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from statsmodels.formula.api import ols

# GitHub CSV Data URL
url = 'https://raw.githubusercontent.com/yuhengding1206/QM2-2024/main/Per%20Attack%20Statistics.csv'

# Load data from GitHub
response = requests.get(url)
df = pd.read_csv(StringIO(response.content.decode('utf-8')))

# Filter the dataset to include only Aden Gulf and Southeast Asia
df = df[df['Region'].isin(['Aden_Gulf', 'Southeast_Asia'])]

# Convert the 'Year' column to numeric type
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')

# Create a variable indicating whether the year is post-2009
df['post'] = np.where(df['Year'] >= 2010, 1, 0)

# Create treatment and control group variables
df['treatment'] = np.where(df['Region'] == 'Aden_Gulf', 1,
                           np.where(df['Region'] == 'Southeast_Asia', 0, np.nan))

# Create an interaction variable to represent the post-intervention state
df['post_treatment'] = df['post'] * df['treatment']

# Create a categorical variable combining treatment and post-period indicators
df['category'] = df['treatment'].astype(str) + df['post'].astype(str)

# Plot a boxplot showing the number of pirate attacks across the categories
sns.boxplot(x='category', y='Per_Attack', hue='treatment', data=df).set_xticklabels(
    ['Pre x Control', 'Pre x Treatment', 'Post x Control', 'Post x Treatment']
)
plt.title('Number of Pirate Attacks by Treatment and Post Periods')
plt.xlabel('')
plt.ylabel('Number of Pirate Attacks')
plt.legend(title='Region')
plt.tight_layout()
plt.show()

# Perform a Differences-in-Differences (DiD) regression
df_model = ols('Per_Attack ~  post + treatment + post_treatment', df).fit()
print(df_model.summary())
# Out:
# <ipython-input-61-95d2ba79748e>:37: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   sns.boxplot(x='category', y='Per_Attack', hue='treatment', data=df).set_xticklabels(
#                             OLS Regression Results
# ...
# Dep. Variable:             Per_Attack   R-squared:                       0.386
# Model:                            OLS   Adj. R-squared:                  0.337
# Method:                 Least Squares   F-statistic:                     7.951
# Date:                Wed, 15 Jan 2025   Prob (F-statistic):           0.000309
# Time:                        16:51:05   Log-Likelihood:                -363.09
# No. Observations:                  42   AIC:                             734.2
# Df Residuals:                      38   BIC:                             741.1
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
